# %% [markdown]
# # Link to GitHub repo with code: https://github.com/prajwalseth/Advanced-ML-HW3/

# %% [markdown]
# ## Can you use the following data to build....?
# 1. A model with an embedding layer and dense layers (but w/ no layers meant for sequential data)
# 2.  A model using Conv1d Layers
# 3.  A model with one sequential layer (LSTM or GRU)
# 4. A model with stacked sequential layers (LSTM or GRU)
# 5. A model with bidirectional sequential layers
#
# ### After choosing a model, feed it some realistic tweets that are not from your training data to see if it returns meaningful/useful results.

# %% [markdown]
# Citation for dataset: Shahi, Gautam Kishore, Anne Dirkson, and Tim A. Majchrzak. "An exploratory study of covid-19 misinformation on twitter." Online Social Networks and Media 22 (2021): 100104.

# %% [markdown]
# ## Import Data

# %%
#Source:Fighting an Infodemic: COVID-19 Fake News Dataset, https://github.com/diptamath/covid_fake_news,https://arxiv.org/abs/2011.03327 

import pandas as pd
trainingdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/Constraint_Train.csv", usecols = ['tweet','label'])
testdata=pd.read_csv("https://raw.githubusercontent.com/diptamath/covid_fake_news/main/data/english_test_with_labels.csv", usecols = ['tweet','label'])

#trainingdata

# %% [markdown]
# ## Present examples of tweets from the dataset that demonstrate real information or misinformation

# %%
real_tweets = list(trainingdata[trainingdata['label'] == 'real']['tweet'])
fake_tweets = list(trainingdata[trainingdata['label'] == 'fake']['tweet'])

# %% [markdown]
# ### Examples of real tweets from the training dataset

# %%
real_tweets[0]
# Out:
# 'The CDC currently reports 99031 deaths. In general the discrepancies in death counts between different sources are small and explicable. The death toll stands at roughly 100000 people today.'

# %%
real_tweets[1]
# Out:
# 'States reported 1121 deaths a small rise from last Tuesday. Southern states reported 640 of those deaths. https://t.co/YASGRTT4ux'

# %%
real_tweets[2]
# Out:
# '#IndiaFightsCorona: We have 1524 #COVID testing laboratories in India and as on 25th August 2020 36827520 tests have been done : @ProfBhargava DG @ICMRDELHI #StaySafe #IndiaWillWin https://t.co/Yh3ZxknnhZ'

# %%
real_tweets[3]
# Out:
# 'Populous states can generate large case counts but if you look at the new cases per million today 9 smaller states are showing more cases per million than California or Texas: AL AR ID KS KY LA MS NV and SC. https://t.co/1pYW6cWRaS'

# %%
real_tweets[4]
# Out:
# 'Covid Act Now found "on average each person in Illinois with COVID-19 is infecting 1.11 other people. Data shows that the infection growth rate has declined over time this factors in the stay-at-home order and other restrictions put in place." https://t.co/hhigDd24fE'

# %% [markdown]
# ### Examples of fake tweets from the training dataset

# %%
fake_tweets[0]
# Out:
# 'Politically Correct Woman (Almost) Uses Pandemic as Excuse Not to Reuse Plastic Bag https://t.co/thF8GuNFPe #coronavirus #nashville'

# %%
fake_tweets[1]
# Out:
# 'Obama Calls Trump’s Coronavirus Response A Chaotic Disaster https://t.co/DeDqZEhAsB'

# %%
fake_tweets[2]
# Out:
# '???Clearly, the Obama administration did not leave any kind of game plan for something like this.??�'

# %%
fake_tweets[3]
# Out:
# 'Retraction—Hydroxychloroquine or chloroquine with or without a macrolide for treatment of COVID-19: a multinational registry analysis - The Lancet https://t.co/L5V2x6G9or'

# %%
fake_tweets[4]
# Out:
# 'The NBA is poised to restart this month. In March we reported on how the Utah Jazz got 58 coronavirus tests in a matter of hours at a time when U.S. testing was sluggish. https://t.co/I8YjjrNoTh https://t.co/o0Nk6gpyos'

# %% [markdown]
# ## Discuss the dataset in general terms and describe why building a predictive model using this data might be practically useful.  Who could benefit from a model like this? Explain.

# %% [markdown]
# The training and test dataset contain 6420 and 2140 rows respectively of COVID-19 related tweets along with a label to signify whether the tweet content is real (verified information) or fake (misinformation). Building a predictive model using this dataset might be practically useful to news organizations who might need to quickly fact-check tweets before reporting them. This would help build trust among the general public, by not allowing tweets containing misinformation to be spread in the news. Building such a predictive model can also benefit researchers who might be interested in ascertaining which politician retweeted the most amount of information.

# %% [markdown]
# ## Define Preprocessor

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Build vocabulary from training text data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(trainingdata.tweet)

# preprocessor tokenizes words and makes sure all documents have the same length
def preprocessor(data, maxlen, max_words):

    sequences = tokenizer.texts_to_sequences(data)

    word_index = tokenizer.word_index
    X = pad_sequences(sequences, maxlen=maxlen)

    return X

# %% [markdown]
# ## Prepare Train and Test Data

# %%
# tokenize and pad X data
X_train = preprocessor(trainingdata.tweet, maxlen=40, max_words=10000)
X_test = preprocessor(testdata.tweet, maxlen=40, max_words=10000)

# ohe encode Y data
y_train = pd.get_dummies(trainingdata.label)
y_test = pd.get_dummies(testdata.label)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6420, 40)
# (2140, 40)

# %% [markdown]
# ## Model 0 (1 embedding layer and 1 dense layer but no layers meant for sequential data)

# %%
from tensorflow.keras.layers import Dense, Embedding,Flatten
from tensorflow.keras.models import Sequential

# replace this model with the architectures from the task description
model = Sequential()
model.add(Embedding(10000, 16, input_length=40))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=32,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 161/161 [==============================] - 1s 5ms/step - loss: 0.5721 - acc: 0.7255 - val_loss: 0.3734 - val_acc: 0.8318
# Epoch 2/10
# 161/161 [==============================] - 1s 4ms/step - loss: 0.3079 - acc: 0.8726 - val_loss: 0.2608 - val_acc: 0.8949
# Epoch 3/10
# 161/161 [==============================] - 1s 4ms/step - loss: 0.1991 - acc: 0.9275 - val_loss: 0.2144 - val_acc: 0.9128
# Epoch 4/10
# 161/161 [==============================] - 1s 3ms/step - loss: 0.1391 - acc: 0.9512 - val_loss: 0.1913 - val_acc: 0.9245
# Epoch 5/10
# 161/161 [==============================] - 1s 4ms/step - loss: 0.1076 - acc: 0.9622 - val_loss: 0.1777 - val_acc: 0.9299
# Epoch 6/10
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0811 - acc: 0.9706 - val_loss: 0.1719 - val_acc: 0.9322
# Epoch 7/10
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0575 - acc: 0.9806 - val_loss: 0.1699 - val_acc: 0.9315
# Epoch 8/10
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0471 - acc: 0.9835 - val_loss: 0.1778 - val_acc: 0.9354
# Epoch 9/10
# 161/161 [==============================] - 1s 3ms/step - loss: 0.0367 - acc: 0.9893 - val_loss: 0.1716 - val_acc: 0.9330
# Epoch 10/10
# 161/161 [==============================] - 1s 4ms/step - loss: 0.0288 - acc: 0.9911 - val_loss: 0.1785 - val_acc: 0.9322

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submit Model 0

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# INFO:tensorflow:Assets written to: /tmp/assets
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 59'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 94.8%, transparent 94.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col4,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col5,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col6,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col7,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col8,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col9,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col10,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col11,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col12,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col13,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col14,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col15,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col16,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col17,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col18,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col19,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col20,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col21,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col22,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col23,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col24,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col25,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col26,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row0_col27,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col4,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col5,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col6,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col7,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col8,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col9,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col10,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col11,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col12,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col13,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col14,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col15,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col16,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col17,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col18,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col19,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col20,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col21,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col22,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col23,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col24,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col25,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col26,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row1_col27,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col4,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col5,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col6,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col7,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col8,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col9,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col10,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col11,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col12,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col13,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col14,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col15,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col16,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col17,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col18,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col19,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col20,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col21,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col22,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col23,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col24,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col25,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col26,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row2_col27,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col4,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col5,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col6,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col7,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col8,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col9,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col10,#T_cc686954_9d37_11eb_aa45_0242ac1c0002row3_col11,#T_cc686954_9d3 ...

# %% [markdown]
# ## Model 1 (two Conv 1D layers)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Embedding, Flatten, MaxPooling1D

model = Sequential()
model.add(Embedding(1000000, 32, input_length=40))
model.add(layers.Conv1D(256, 5)) 
model.add(MaxPooling1D(pool_size=4))
model.add(layers.Conv1D(32, 7)) 
model.add(Flatten())
model.add(Dense(2, activation='softmax'))


model.compile(optimizer='adam', loss='mse', metrics=['acc'])


history = model.fit(X_train, y_train,
                    epochs=3,
                    batch_size=40,
                    validation_split=0.2)
# Out:
# Epoch 1/3
# 129/129 [==============================] - 45s 347ms/step - loss: 0.1539 - acc: 0.7769 - val_loss: 0.0655 - val_acc: 0.9112
# Epoch 2/3
# 129/129 [==============================] - 49s 380ms/step - loss: 0.0264 - acc: 0.9666 - val_loss: 0.0577 - val_acc: 0.9229
# Epoch 3/3
# 129/129 [==============================] - 44s 338ms/step - loss: 0.0063 - acc: 0.9933 - val_loss: 0.0563 - val_acc: 0.9276

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submit Model 1

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# INFO:tensorflow:Assets written to: /tmp/assets
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 53'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 94.8%, transparent 94.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col4,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col5,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col6,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col7,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col8,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col9,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col10,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col11,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col12,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col13,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col14,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col15,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col16,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col17,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col18,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col19,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col20,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col21,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col22,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col23,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col24,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col25,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col26,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row0_col27,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col4,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col5,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col6,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col7,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col8,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col9,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col10,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col11,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col12,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col13,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col14,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col15,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col16,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col17,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col18,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col19,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col20,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col21,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col22,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col23,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col24,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col25,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col26,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row1_col27,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col4,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col5,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col6,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col7,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col8,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col9,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col10,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col11,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col12,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col13,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col14,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col15,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col16,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col17,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col18,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col19,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col20,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col21,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col22,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col23,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col24,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col25,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col26,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row2_col27,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col4,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col5,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col6,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col7,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col8,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col9,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col10,#T_24c0a03e_9d34_11eb_aa45_0242ac1c0002row3_col11,#T_24c0a03e_9d3 ...

# %% [markdown]
# ## Model 2 (one LSTM layer with dropout)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(Embedding(10000, 8, input_length=40))
model.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2)) 
model.add(Dense(2, activation='softmax'))


model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])


history = model.fit(X_train, y_train,
                    epochs=6,
                    batch_size=40,
                    validation_split=0.2)
# Out:
# Epoch 1/6
# 129/129 [==============================] - 11s 55ms/step - loss: 0.5458 - acc: 0.7188 - val_loss: 0.2913 - val_acc: 0.8746
# Epoch 2/6
# 129/129 [==============================] - 6s 49ms/step - loss: 0.2587 - acc: 0.9033 - val_loss: 0.2276 - val_acc: 0.9136
# Epoch 3/6
# 129/129 [==============================] - 6s 50ms/step - loss: 0.1635 - acc: 0.9386 - val_loss: 0.2075 - val_acc: 0.9268
# Epoch 4/6
# 129/129 [==============================] - 6s 49ms/step - loss: 0.1301 - acc: 0.9504 - val_loss: 0.1818 - val_acc: 0.9330
# Epoch 5/6
# 129/129 [==============================] - 6s 49ms/step - loss: 0.0950 - acc: 0.9647 - val_loss: 0.1959 - val_acc: 0.9369
# Epoch 6/6
# 129/129 [==============================] - 6s 48ms/step - loss: 0.0880 - acc: 0.9691 - val_loss: 0.2329 - val_acc: 0.9346

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submit Model 2

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# INFO:tensorflow:Assets written to: /tmp/assets
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 55'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 94.8%, transparent 94.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col4,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col5,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col6,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col7,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col8,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col9,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col10,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col11,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col12,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col13,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col14,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col15,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col16,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col17,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col18,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col19,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col20,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col21,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col22,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col23,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col24,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col25,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col26,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row0_col27,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col4,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col5,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col6,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col7,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col8,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col9,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col10,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col11,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col12,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col13,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col14,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col15,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col16,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col17,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col18,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col19,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col20,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col21,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col22,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col23,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col24,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col25,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col26,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row1_col27,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col4,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col5,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col6,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col7,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col8,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col9,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col10,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col11,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col12,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col13,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col14,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col15,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col16,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col17,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col18,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col19,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col20,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col21,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col22,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col23,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col24,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col25,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col26,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row2_col27,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col4,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col5,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col6,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col7,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col8,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col9,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col10,#T_105256b8_9d36_11eb_aa45_0242ac1c0002row3_col11,#T_105256b8_9d3 ...

# %% [markdown]
# ## Model 3 (Stacked LSTM with dropout)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Embedding, Bidirectional
from tensorflow.keras.layers import LSTM, SimpleRNN, Dense

model = Sequential()

model.add(Embedding(10000, 8, input_length=40))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])


history = model.fit(X_train, y_train,
                    epochs=5,
                    batch_size=40,
                    validation_split=0.2)
# Out:
# Epoch 1/5
# 129/129 [==============================] - 18s 84ms/step - loss: 0.4909 - acc: 0.7609 - val_loss: 0.2805 - val_acc: 0.8894
# Epoch 2/5
# 129/129 [==============================] - 10s 74ms/step - loss: 0.1822 - acc: 0.9296 - val_loss: 0.2115 - val_acc: 0.9206
# Epoch 3/5
# 129/129 [==============================] - 9s 70ms/step - loss: 0.1264 - acc: 0.9504 - val_loss: 0.3323 - val_acc: 0.8832
# Epoch 4/5
# 129/129 [==============================] - 9s 71ms/step - loss: 0.0842 - acc: 0.9665 - val_loss: 0.2258 - val_acc: 0.9291
# Epoch 5/5
# 129/129 [==============================] - 10s 74ms/step - loss: 0.0703 - acc: 0.9742 - val_loss: 0.2079 - val_acc: 0.9346

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submit Model 3

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_80_layer_call_and_return_conditional_losses, lstm_cell_80_layer_call_fn, lstm_cell_80_layer_call_fn, lstm_cell_80_layer_call_and_return_conditional_losses, lstm_cell_80_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_80_layer_call_and_return_conditional_losses, lstm_cell_80_layer_call_fn, lstm_cell_80_layer_call_fn, lstm_cell_80_layer_call_and_return_conditional_losses, lstm_cell_80_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/assets
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 56'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 94.8%, transparent 94.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col4,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col5,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col6,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col7,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col8,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col9,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col10,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col11,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col12,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col13,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col14,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col15,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col16,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col17,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col18,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col19,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col20,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col21,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col22,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col23,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col24,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col25,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col26,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row0_col27,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col4,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col5,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col6,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col7,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col8,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col9,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col10,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col11,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col12,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col13,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col14,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col15,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col16,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col17,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col18,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col19,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col20,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col21,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col22,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col23,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col24,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col25,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col26,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row1_col27,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col4,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col5,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col6,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col7,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col8,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col9,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col10,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col11,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col12,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col13,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col14,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col15,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col16,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col17,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col18,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col19,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col20,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col21,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col22,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col23,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col24,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col25,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col26,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row2_col27,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col4,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col5,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col6,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col7,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col8,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col9,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col10,#T_79e4811e_9d36_11eb_aa45_0242ac1c0002row3_col11,#T_79e4811e_9d3 ...

# %% [markdown]
# ## Model 4 (Bidirectional LSTM)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Embedding, Bidirectional
from tensorflow.keras.layers import LSTM

model = Sequential()
model.add(Embedding(100000, 32, input_length=40))
model.add(Bidirectional(LSTM(32, return_sequences=True)))
model.add(Bidirectional(LSTM(10)))
model.add(Dense(2, activation='softmax'))


model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])


history = model.fit(X_train, y_train,
                    epochs=10,
                    batch_size=40,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 129/129 [==============================] - 20s 91ms/step - loss: 0.4472 - acc: 0.7786 - val_loss: 0.2338 - val_acc: 0.9058
# Epoch 2/10
# 129/129 [==============================] - 10s 75ms/step - loss: 0.1398 - acc: 0.9455 - val_loss: 0.2010 - val_acc: 0.9151
# Epoch 3/10
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0889 - acc: 0.9659 - val_loss: 0.2109 - val_acc: 0.9229
# Epoch 4/10
# 129/129 [==============================] - 10s 76ms/step - loss: 0.0512 - acc: 0.9813 - val_loss: 0.2483 - val_acc: 0.9167
# Epoch 5/10
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0386 - acc: 0.9853 - val_loss: 0.2750 - val_acc: 0.9206
# Epoch 6/10
# 129/129 [==============================] - 10s 76ms/step - loss: 0.0238 - acc: 0.9895 - val_loss: 0.2815 - val_acc: 0.9369
# Epoch 7/10
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0180 - acc: 0.9925 - val_loss: 0.3355 - val_acc: 0.9291
# Epoch 8/10
# 129/129 [==============================] - 10s 75ms/step - loss: 0.0134 - acc: 0.9944 - val_loss: 0.3972 - val_acc: 0.9283
# Epoch 9/10
# 129/129 [==============================] - 10s 77ms/step - loss: 0.0119 - acc: 0.9953 - val_loss: 0.4561 - val_acc: 0.9260
# Epoch 10/10
# 129/129 [==============================] - 10s 77ms/step - loss: 0.0048 - acc: 0.9988 - val_loss: 0.4302 - val_acc: 0.9213

# %%
# format y_pred as labels 
y_pred = model.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Submit Model 4

# %%
# install aimodelshare library
# %%capture
! pip install aimodelshare --upgrade --extra-index-url https://test.pypi.org/simple/

# %%
import aimodelshare as ai
from aimodelshare.aimsonnx import model_to_onnx

# %%
# save preprocessor
ai.export_preprocessor(preprocessor,"")

# %%
# save model in onnx format
onnx_model = model_to_onnx(model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("onnx_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_83_layer_call_and_return_conditional_losses, lstm_cell_83_layer_call_fn, lstm_cell_84_layer_call_and_return_conditional_losses, lstm_cell_84_layer_call_fn, lstm_cell_86_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as lstm_cell_83_layer_call_and_return_conditional_losses, lstm_cell_83_layer_call_fn, lstm_cell_84_layer_call_and_return_conditional_losses, lstm_cell_84_layer_call_fn, lstm_cell_86_layer_call_and_return_conditional_losses while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/assets
# INFO:tensorflow:Assets written to: /tmp/assets

# %%
# set credentials for modeltoapi function 
# make sure you have uploaded your credentials.txt file
from aimodelshare.aws import set_credentials
api_url = "https://wvr23l2z9i.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=api_url,credential_file="credentials.txt", type="submit_model", manual=False)
# Out:
# AI Model Share login credentials set successfully.
# AWS credentials set successfully.

# %%
# submit model and predictions to competition
ai.submit_model("onnx_model.onnx",
                api_url,
                prediction_submission=predicted_labels,
                preprocessor="preprocessor.zip")
# Out:
# 'Your model has been submitted as model version 57'

# %%
# check leaderboard
data=ai.get_leaderboard(api_url, verbose=3)
ai.leaderboard.stylize_leaderboard(data)
# Out:
# <style  type="text/css" >
# #T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col0{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f8d6 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col1{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#c778c8 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col2{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff4971 94.8%, transparent 94.8%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col3{
#             text-align:  center;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aadbaa 94.9%, transparent 94.9%);
#             color:  #251e1b;
#             font-size:  12px;
#         }#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col4,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col5,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col6,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col7,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col8,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col9,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col10,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col11,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col12,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col13,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col14,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col15,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col16,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col17,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col18,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col19,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col20,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col21,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col22,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col23,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col24,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col25,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col26,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row0_col27,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col4,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col5,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col6,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col7,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col8,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col9,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col10,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col11,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col12,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col13,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col14,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col15,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col16,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col17,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col18,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col19,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col20,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col21,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col22,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col23,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col24,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col25,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col26,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row1_col27,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col4,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col5,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col6,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col7,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col8,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col9,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col10,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col11,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col12,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col13,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col14,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col15,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col16,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col17,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col18,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col19,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col20,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col21,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col22,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col23,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col24,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col25,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col26,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row2_col27,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col4,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col5,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col6,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col7,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col8,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col9,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col10,#T_046e5daa_9d37_11eb_aa45_0242ac1c0002row3_col11,#T_046e5daa_9d3 ...

# %% [markdown]
# ## Discuss which models performed better and point out relevant hyper-parameter values for successful models.

# %% [markdown]
# In my experience, my model with 1 Embedding layer, 2 Conv1D layers, 1 max pooling layer, 1 flatten layer and 1 Dense layer performed the best. The summary of the model is below.

# %%
 bestmodel_prajwal_1 = ai.aimsonnx.instantiate_model(api_url, version=40) 

 bestmodel_prajwal_1.summary()
# Out:
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_68 (Embedding)     (None, 40, 8)             80000
# _________________________________________________________________
# conv1d_109 (Conv1D)          (None, 36, 256)           10496
# _________________________________________________________________
# max_pooling1d_39 (MaxPooling (None, 9, 256)            0
# _________________________________________________________________
# conv1d_110 (Conv1D)          (None, 3, 32)             57376
# _________________________________________________________________
# flatten_43 (Flatten)         (None, 96)                0
# _________________________________________________________________
# dense_52 (Dense)             (None, 2)                 194
# =================================================================
# Total params: 148,066
# Trainable params: 148,066
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The second best model of mine had 1 Embedding layer, 1 LSTM layer and 1 Dense layer. The model parameters are below.

# %%
 bestmodel_prajwal_2 = ai.aimsonnx.instantiate_model(api_url, version=41) 

 bestmodel_prajwal_2.summary()
# Out:
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_74 (Embedding)     (None, 40, 8)             80000
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 64)                18688
# _________________________________________________________________
# dense_58 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 98,818
# Trainable params: 98,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# My third best model also had 1 Embedding layer, 2 Conv1D layers, 1 Max pooling layer, 1 Flatten layer and 1 Dense layer (similar to my best performing model). However, it differed from my best performing model in that the number of parameters for the Embedding and two Conv1D layers were much more. The model parameters are below.

# %%
 bestmodel_prajwal_3 = ai.aimsonnx.instantiate_model(api_url, version=51) 

 bestmodel_prajwal_3.summary()
# Out:
# Model: "sequential_118"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_114 (Embedding)    (None, 40, 32)            32000000
# _________________________________________________________________
# conv1d_166 (Conv1D)          (None, 36, 256)           41216
# _________________________________________________________________
# max_pooling1d_67 (MaxPooling (None, 9, 256)            0
# _________________________________________________________________
# conv1d_167 (Conv1D)          (None, 3, 32)             57376
# _________________________________________________________________
# flatten_71 (Flatten)         (None, 96)                0
# _________________________________________________________________
# dense_103 (Dense)            (None, 2)                 194
# =================================================================
# Total params: 32,098,786
# Trainable params: 32,098,786
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Import the best model from the leader board (whatever the best model is after your final submission). Visualize the model's structure using tf.kera's model.summary(). Explain how the model's structure is different from your best model.

# %%
 # Get best model architecture and view model summary, change version arg as needed
 
 bestmodel = ai.aimsonnx.instantiate_model(api_url, version=19) 

 bestmodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 40, 100)           1000000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40, 32)            17024
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                16600
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 82
# =================================================================
# Total params: 1,035,746
# Trainable params: 1,035,746
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compare two model versions to see diffs
ai.aimsonnx.compare_models(api_url, version_list=[19,40])
# Out:
# <style  type="text/css" >
# #T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col0,#T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col0,#T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col3{
#             background:  tomato;
#         }</style><table id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model_19_Layer</th>        <th class="col_heading level0 col1" >Model_19_Shape</th>        <th class="col_heading level0 col2" >Model_19_Params</th>        <th class="col_heading level0 col3" >Model_40_Layer</th>        <th class="col_heading level0 col4" >Model_40_Shape</th>        <th class="col_heading level0 col5" >Model_40_Params</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col0" class="data row0 col0" >Embedding</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col1" class="data row0 col1" >(None, 40, 100)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col2" class="data row0 col2" >1000000.000000</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col3" class="data row0 col3" >Embedding</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col4" class="data row0 col4" >(None, 40, 8)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row0_col5" class="data row0 col5" >80000</td>
#             </tr>
#             <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col0" class="data row1 col0" >LSTM</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col1" class="data row1 col1" >(None, 40, 32)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col2" class="data row1 col2" >17024.000000</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col3" class="data row1 col3" >Conv1D</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col4" class="data row1 col4" >(None, 36, 256)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row1_col5" class="data row1 col5" >10496</td>
#             </tr>
#             <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col0" class="data row2 col0" >LSTM</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col1" class="data row2 col1" >(None, 50)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col2" class="data row2 col2" >16600.000000</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col3" class="data row2 col3" >MaxPooling1D</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col4" class="data row2 col4" >(None, 9, 256)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row2_col5" class="data row2 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col0" class="data row3 col0" >Dense</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col1" class="data row3 col1" >(None, 40)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col2" class="data row3 col2" >2040.000000</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col3" class="data row3 col3" >Conv1D</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col4" class="data row3 col4" >(None, 3, 32)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row3_col5" class="data row3 col5" >57376</td>
#             </tr>
#             <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col0" class="data row4 col0" >Dense</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col1" class="data row4 col1" >(None, 2)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col2" class="data row4 col2" >82.000000</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col3" class="data row4 col3" >Flatten</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col4" class="data row4 col4" >(None, 96)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row4_col5" class="data row4 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col0" class="data row5 col0" >nan</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col3" class="data row5 col3" >Dense</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col4" class="data row5 col4" >(None, 2)</td>
#                         <td id="T_c54beba4_9d38_11eb_aa45_0242ac1c0002row5_col5" class="data row5 col5" >194</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The best model is made of 1 Embedding layer, 2 LSTM layers, and 2 Dense layers. My best model is made of 1 Embedding layer, 2 Conv1D layers, 1 Maxpooling1D layer, 1 Flatten layer and 1 Dense layer. The best model has a completely different architecture as it chooses to stack two LSTM's instead of two Conv1D layers. The total number of model parameters is also more than that of my best model (1,035,746 vs 148,066)

# %% [markdown]
# ## Fit the best model from the leader board to training data and evaluate it on test data to complete your report.

# %%
bestmodel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])


history = bestmodel.fit(X_train, y_train,
                    epochs=10,
                    batch_size=40,
                    validation_split=0.2)
# Out:
# Epoch 1/10
# 129/129 [==============================] - 13s 68ms/step - loss: 0.4300 - acc: 0.8015 - val_loss: 0.3110 - val_acc: 0.8583
# Epoch 2/10
# 129/129 [==============================] - 8s 58ms/step - loss: 0.1367 - acc: 0.9423 - val_loss: 0.2468 - val_acc: 0.8980
# Epoch 3/10
# 129/129 [==============================] - 7s 58ms/step - loss: 0.0771 - acc: 0.9729 - val_loss: 0.2117 - val_acc: 0.9315
# Epoch 4/10
# 129/129 [==============================] - 8s 59ms/step - loss: 0.0462 - acc: 0.9837 - val_loss: 0.2078 - val_acc: 0.9283
# Epoch 5/10
# 129/129 [==============================] - 8s 61ms/step - loss: 0.0277 - acc: 0.9896 - val_loss: 0.3455 - val_acc: 0.9276
# Epoch 6/10
# 129/129 [==============================] - 8s 59ms/step - loss: 0.0116 - acc: 0.9956 - val_loss: 0.4028 - val_acc: 0.9322
# Epoch 7/10
# 129/129 [==============================] - 8s 59ms/step - loss: 0.0067 - acc: 0.9972 - val_loss: 0.6962 - val_acc: 0.9260
# Epoch 8/10
# 129/129 [==============================] - 7s 54ms/step - loss: 0.0062 - acc: 0.9990 - val_loss: 0.6367 - val_acc: 0.9229
# Epoch 9/10
# 129/129 [==============================] - 7s 58ms/step - loss: 3.0818e-04 - acc: 1.0000 - val_loss: 0.9378 - val_acc: 0.9159
# Epoch 10/10
# 129/129 [==============================] - 8s 58ms/step - loss: 5.3736e-04 - acc: 0.9997 - val_loss: 0.8832 - val_acc: 0.9206

# %%
# format y_pred as labels 
y_pred = bestmodel.predict(X_test).argmax(axis=1)
predicted_labels = [y_test.columns[i] for i in y_pred]
predicted_labels[0:5]
# Out:
# ['real', 'fake', 'fake', 'real', 'real']

# %% [markdown]
# ## Complete your report by feeding your model some realistic tweets  to see if it returns meaningful/useful results (these tweets can be found online or you can create them yourself).

# %%
# All these tweets should give us a 1 for being misinformation. I found them while browsing through Twitter

realistic_tweets = ["Let's not forget chloroquine/hydroxychloroquine, the efficacy of which has been well known to the NIH, Fauci et al. for the best part of SIXTEEN years now, but which, at roughly $20 per treatment per patient, apparently lacks suitable profit margins.",
                    'This is the same year Bill Gates said we would be a deadly pandemic. 2005!  What a coincidence!',
                    "While #Fauci intentionally lies. This man speaks. Dark to light",
                    "As the country starts opening up, #Fauci tries to explain away why states like #Florida & #Texas, without mask mandates and open to full capacity, have plummeting case rates.",
                    "#Fauci Funded the #Wuhan Research that Created Corona-19 https://paulcraigroberts.org/2021/04/08/fauci-funded-the-wuhan-research-that-created-corona-19/",
                    "SCAMDEMIC!!! CONFUSION: Hundreds Testing Positive for Covid After Being Fully Vaccinated! https://infowars.com/posts/confusion-hundreds-testing-positive-for-covid-after-being-fully-vaccinated/ #MAGA #Trump",
                    "No vaccine for HIV after almost 50 years of research. No vaccine for the common cold after over 100 years. But hey, COVID appears out of nowhere and within an year bam, We got a vaccine. I thought we shouldn’t peer pressure one another into trying experimental drugs. #maga",
                    "I noticed that too. The tracking chip has better cell and satellite coverage. #MAGA get your #Covid_19 tracking chip.",
                    ]
transform_tweets = preprocessor(realistic_tweets, maxlen=40, max_words=10000)
bestmodel_prajwal_1.predict(transform_tweets).argmax(axis=1) # performance of my best model
# Out:
# array([0, 0, 0, 1, 0, 0, 0, 1])

# %%
bestmodel.predict(transform_tweets).argmax(axis=1) # performance of the best model from the leaderboard on realistic tweets
# Out:
# array([1, 0, 0, 1, 0, 0, 0, 0])
